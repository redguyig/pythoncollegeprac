# %%
import pandas as pd 
import numpy as np 
import matplotlib as plt 
import seaborn as sns

# %%
data = sns.load_dataset("iris")

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data['species']=data['species'].map({ "setosa": 0 , "versicolor": 1 , "virginica": 2 })  #simpler method
#alternate method we can use for preprocessing 
# from sklearn.preprocessing import LabelEncoder
# le=LaberlEncoder()
# data['species']=le.fit_transform(data['species'])

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
x=data.iloc[:,:-1]  #excludes the last value in the column which is the output column 
y=data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=69)

# %%
from sklearn.tree import DecisionTreeClassifier
#for confusion matrix we use accuracy,recall,f1_score,epsio

# %%
model= DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
para={
    "criterion":['gini','entropy','log_loss'],
    "splitter":["best","random"],
    "max_depth":[1,2,3,4,5,6]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
gd_model=GridSearchCV(model,param_grid=para,cv=3,scoring="accuracy")

# %%
gd_model.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [1, 2, 3, 4, 5, 6],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy')

# %%
gd_model.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 5, 'splitter': 'random'}

# %%
y_pred=gd_model.predict(x_test)

# %%
from sklearn.metrics import classification_report, accuracy_score,confusion_matrix

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       0.86      1.00      0.92        12
#            2       1.00      0.88      0.94        17
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.96      0.95        45
# weighted avg       0.96      0.96      0.96        45

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9555555555555556

# %%
from sklearn.linear_model import LogisticRegression

# %%
logi_model=LogisticRegression()

# %%
import warnings 
warnings.filterwarnings("ignore") #used because logi_model uses more iterations hence to avvoid the errors

# %%
logi_model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y1_pred=logi_model.predict(x_test)

# %%
x1_pred=logi_model.predict(x_train)

# %%
print("Logistic Regression Training accuracy is:",accuracy_score(y_test,y1_pred))
# Out:
# Logistic Regression training accuracy is: 0.9777777777777777

# %%
print("Logistic Regression Testing Accuracy is:", accuracy_score(y_train,x1_pred))
# Out:
# Logistic Regression Testing Accuracy is: 0.9619047619047619

# %% [markdown]
# ### KNN (k-nearest neighbors) uses the euclidean formula underoot (x2-x1)^2+(y2-y1)^2
# it's a lazy approach since in training it just stores the data and for testing it does all the work of calculating the distance of all the points form the given value
# here k will be the no. of points with which it is compaared for least distance
# graph will be used where distance is plotted on y axis and values on x axis then a graph which looks like a smooth L is formed where the elbow of L decides the K
# ![image.png](attachment:4d0826d4-bb01-464b-9f5f-89b6f53d025d.png)![image.png](attachment:bf0abeb4-b097-469e-8e76-9e73fbc45b24.png)

# %% [markdown]
# ### SVM (support vector machine) uses planes to classify data

# %%
from sklearn.neighbors import KNeighborsClassifier # for knn algo

# %%
from sklearn.svm import SVC #for svm algo

# %%
knn=KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=knn.predict(x_test)
x_pred=knn.predict(x_train)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm = confusion_matrix(y_test, y_pred)
ac = accuracy_score(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 2
#       1 from sklearn.metrics import confusion_matrix,accuracy_score
# ----> 2 cm = confusion_matrix(y_test, y_pred)
#       3 ac = accuracy_score(y_test,y_pred)
#
# File ~\Documents\AIandshicllg\Lib\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File ~\Documents\AIandshicllg\Lib\site-packages\sklearn\metrics\_classification.py:340, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     257 """Compute confusion matrix to evaluate the accuracy of a classification.
#     258
#     259 By definition a confusion matrix :math:`C` is such that :math:`C_{i, j}`
#    (...)
#     337 (np.int64(0), np.int64(2), np.int64(1), np.int64(1))
#     338 """
#     339 y_true, y_pred = attach_unique(y_true, y_pred)
# --> 340 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     341 if y_type not in ("binary", "multiclass"):
#     342     raise ValueError("%s is not supported" % y_type)
#
# File ~\Documents\AIandshicllg\Lib\site-packages\sklearn\metrics\_classification.py:98, in _check_targets(y_true, y_pred)
#      71 """Check that y_true and y_pred belong to the same classification task.
#      72
#      73 This converts multiclass or binary types to a common shape, and raises a
#    (...)
#      95 y_pred : array or indicator matrix
#      96 """
#      97 xp, _ = get_namespace(y_true, y_pred)
# ---> 98 check_consistent_length(y_true, y_pred)
#      99 type_true = type_of_target(y_true, input_name="y_true")
#     100 type_pred = type_of_target(y_pred, input_name="y_pred")
#
# File ~\Documents\AIandshicllg\Lib\site-packages\sklearn\utils\validation.py:475, in check_consistent_length(*arrays)
#     473 uniques = np.unique(lengths)
#     474 if len(uniques) > 1:
# --> 475     raise ValueError(
#     476         "Found input variables with inconsistent numbers of samples: %r"
#     477         % [int(l) for l in lengths]
#     478     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [105, 45]

# %%
print(cm)

# %%
print(ac)
# Out:
# 0.9777777777777777
